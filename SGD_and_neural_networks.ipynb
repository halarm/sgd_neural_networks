# %% [markdown]
# # Introduction

# %% [markdown]
# The example of 3's and 7's is a binary prediction as the data we have is either a 3 or a 7 and Jeremy denotes that in his lecture as a numerial attribution, 1.0 if it's a 3 or 0.0 if 7; the output is essentially just single and inputs are the matrix or the 'representation' of the 3 in pixels as the inputs.

# %% [markdown]
# That's essentially what a neuron (bulding block of neural network) is with inputs and an output: our brain is able to take that matrix and give an output of whether it is a three or not.

# %% [markdown]
# ![neurons.svg](attachment:neurons.svg)

# %%
import fastai
from fastai import *
import torch
from torch import Tensor

# %%
_three_in_pixels = [0.,1.,1.] #Inputs: 1 row, 3 columns
_three_in_pixels
# Out:
# [0.0, 1.0, 1.0]

# %%
#torch representation
three_in_pixels = Tensor(_three_in_pixels)
three_in_pixels.shape #what rank is this tensor?
three_in_pixels.mean().item()
# Out:
# 0.6666666865348816

# %%
_scalar_prediction_for_three = 0.64

_prediction_for_three = [.12, 1.,.8]

prediction_for_three = Tensor(_prediction_for_three)

prediction_for_three.shape
prediction_for_three.mean().item()
# Out:
# 0.64000004529953

# %% [markdown]
# How would we find the loss?

# %%
[1- pred if target == 1.0 else pred for pred, target in zip(_prediction_for_three,_three_in_pixels)]
# Out:
# [0.12, 0.0, 0.19999999999999996]

# %% [markdown]
# How would we do this in torch.where??

# %%
#INSERT LIVE THE FORMULA

# %% [markdown]
# Now, that was just a rank-1 representation of a three and just one three and how would one turn a matrix representation into a three or not a  three (seven). Enter the sigmoid function.

# %% [markdown]
# ![sigmoid.webp](attachment:sigmoid.webp)
